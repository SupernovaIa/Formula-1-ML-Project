# %% [markdown]
# # 1. Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px

import fastf1.plotting

# Config less verbosity
fastf1.set_log_level('ERROR')

import plotly.graph_objects as go
import fastf1.plotting

# %%
import sys

sys.path.append('../')

from src.dashboard.race import *

# %% [markdown]
# # 2. Data loading

# %% [markdown]
# We only need to load the session

# %%
# Monaco GP 2023
season = 2023
rnd = 'Monaco'

# %%
session = fastf1.get_session(season, rnd, 'R')
session.load(telemetry=True, weather=True)

# %%
session.get_driver('VER')['FullName']
# Out:
# 'Max Verstappen'

# %% [markdown]
# # 3. Dashboard

# %% [markdown]
# ## 3.1 Position changes

# %%
plot_position_changes(session)

# %% [markdown]
# ## 3.2 Results

# %% [markdown]
# ### Race results

# %%
get_race_results(session)
# Out:
#    ClassifiedPosition         FullName DriverNumber CountryCode  \
# 1                   1   Max Verstappen            1         NED
# 14                  2  Fernando Alonso           14         ESP
# 31                  3     Esteban Ocon           31         FRA
# 44                  4   Lewis Hamilton           44         GBR
# 63                  5   George Russell           63         GBR
# 16                  6  Charles Leclerc           16         MON
# 10                  7     Pierre Gasly           10         FRA
# 55                  8     Carlos Sainz           55         ESP
# 4                   9     Lando Norris            4         GBR
# 81                 10    Oscar Piastri           81         AUS
# 77                 11  Valtteri Bottas           77         FIN
# 21                 12    Nyck De Vries           21         NED
# 24                 13      Guanyu Zhou           24         CHN
# 23                 14  Alexander Albon           23         THA
# ...

# %%
plot_results(session)

# %% [markdown]
# ### Qualifying results

# %% [markdown]
# We need to load a qualifying session

# %%
session_qualy = fastf1.get_session(season, rnd, 'Q')
session_qualy.load(telemetry=True, weather=False)

# %%
get_qualy_results(session_qualy)
# Out:
#     Position         FullName DriverNumber CountryCode         TeamName  \
# 1        1.0   Max Verstappen            1         NED  Red Bull Racing
# 14       2.0  Fernando Alonso           14         ESP     Aston Martin
# 16       3.0  Charles Leclerc           16         MON          Ferrari
# 31       4.0     Esteban Ocon           31         FRA           Alpine
# 55       5.0     Carlos Sainz           55         ESP          Ferrari
# 44       6.0   Lewis Hamilton           44         GBR         Mercedes
# 10       7.0     Pierre Gasly           10         FRA           Alpine
# 63       8.0   George Russell           63         GBR         Mercedes
# 22       9.0     Yuki Tsunoda           22         JPN       AlphaTauri
# 4       10.0     Lando Norris            4         GBR          McLaren
# 81      11.0    Oscar Piastri           81         AUS          McLaren
# 21      12.0    Nyck De Vries           21         NED       AlphaTauri
# ...

# %%
plot_fastest_laps(session_qualy)

# %% [markdown]
# ## 3.3 Track map

# %%
draw_track(session)

# %% [markdown]
# ## 3.4 Race pace

# %% [markdown]
# ### Drivers

# %% [markdown]
# Nota: Añadir a estas funciones las opciones de box, points

# %%
plot_drivers_pace(session, kind='compound', threshold=1.5)

# %%
plot_drivers_pace(session, box=True)

# %% [markdown]
# ### Constructors

# %%
plot_teams_pace(session, box=True)

# %% [markdown]
# ## 3.5 Tyre strategies

# %%
plot_tyre_strat(session)

# %% [markdown]
# ## 3.6 Qualifying laps telemetry

# %% [markdown]
# ### Pole position

# %%
plot_telemetry(session_qualy)

# %% [markdown]
# ### Comparison

# %% [markdown]
# Nota: Aquí podríamos añadir un gráfico que sea un delta para ver dónde pierden o ganan

# %%
plot_telemetry(session_qualy, mode='Speed', drivers=['VER', 'ALO'])

# %% [markdown]
# ## 3.7 Race fastest laps

# %%
plot_fastest_laps(session)

# %% [markdown]
# ### Drivers race pace

# %%
plot_driver_pace(session, 'VER', threshold=1.5)
